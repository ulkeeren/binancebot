# %%
from binance import Client
import pandas as pd
import numpy as np
client = Client(api_key="iPQMe46exUy10KiBaBahQT7ow1uzb9jaxlKj19Bg5BI8JEwJL5bw9LCvJtfKuVbP",api_secret="J4FGJQdGPpNGm8jpnj3IuFuDJuAe7FIa3cM51L4z662UYux3qD0ByLJ0bfIltZvK")

# %%
prices = client.get_all_tickers()
prices
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.05362000'},
#  {'symbol': 'LTCBTC', 'price': '0.00158500'},
#  {'symbol': 'BNBBTC', 'price': '0.00698800'},
#  {'symbol': 'NEOBTC', 'price': '0.00025690'},
#  {'symbol': 'QTUMETH', 'price': '0.00125400'},
#  {'symbol': 'EOSETH', 'price': '0.00030730'},
#  {'symbol': 'SNTETH', 'price': '0.00001676'},
#  {'symbol': 'BNTETH', 'price': '0.00030980'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00013130'},
#  {'symbol': 'BNBETH', 'price': '0.13030000'},
#  {'symbol': 'BTCUSDT', 'price': '42899.51000000'},
#  {'symbol': 'ETHUSDT', 'price': '2300.10000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00000024'},
# ...
